# %%
using Revise, Pkg
Pkg.activate()
Pkg.status()
plotly(size=(400, 500))
includet("research/CDResearch.jl")
# Out:
#   Activating project at `~/.julia/environments/v1.9`
# Status `~/.julia/environments/v1.9/Project.toml`
#   [537997a7] AbstractPlotting v0.18.3
#   [6e4b80f9] BenchmarkTools v1.3.2
# ⌅ [764a87c0] BoundaryValueDiffEq v2.11.0
#   [336ed68f] CSV v0.10.11
# ⌅ [052768ef] CUDA v3.13.1
# ⌅ [13f3f980] CairoMakie v0.6.2
#   [35d6a980] ColorSchemes v3.21.0
#   [5ae59095] Colors v0.12.10
#   [a462cd4a] CondensateDynamics v0.1.0 `~/.julia/dev/CondensateDynamics`
#   [459566f4] DiffEqCallbacks v2.26.1
# ⌃ [071ae1c0] DiffEqGPU v1.26.0
# ⌃ [0c46a032] DifferentialEquations v7.6.0
#   [b305315f] Elliptic v1.0.1
# ⌃ [7a1cc6ca] FFTW v1.6.0
# ⌃ [e9467ef8] GLMakie v0.4.2
#   [28b8d3ca] GR v0.72.7
#   [f67ccb44] HDF5 v0.16.15
#   [7073ff75] IJulia v1.24.2
#   [d0351b0e] InspectDR v0.4.3
#   [a98d9a8b] Interpolations v0.14.7
#   [d1acc4aa] IntervalArithmetic v0.20.9
#   [d2bf35a9] IntervalRootFinding v0.5.11
#   [033835bb] JLD2 v0.4.31
#   [0f8b85d8] JSON3 v1.13.1
# ⌅ [929cbde3] LLVM v4.17.1
# ...

# %%
dynsim = load_parameters_dy()
g1 = dynsim["G1"]
show_psi_0(g1)
single_shot_dynamics(g1)
# Out:
# ┌ Info: (200,)
# └ @ Main /home/lorenzi/.julia/dev/CondensateDynamics/research/visual_utils.jl:5
# ...

# %%
prepare_in_ground_state!(g1)
show_psi_0(g1)
single_shot_dynamics(g1)
# Out:
# ┌ Info: Computing ground state...
# └ @ Main /home/lorenzi/.julia/dev/CondensateDynamics/research/simulations_parameters.jl:271
# 1024-element Vector{ComplexF64}:
#   0.002687791721494342 - 6.97493460386473e-15im
#   0.002625610867451805 - 7.005602988456508e-15im
#  0.0025648685526629095 - 7.0058358014928374e-15im
#  0.0025055314999009614 - 7.046030538435501e-15im
#   0.002447567201602656 - 7.012751096200938e-15im
#   0.002390943902077047 - 7.0032334476212374e-15im
#   0.002335630580125231 - 7.051100817627402e-15im
#  0.0022815969320615264 - 7.014875477099926e-15im
#  0.0022288133551261746 - 7.006686878297371e-15im
#  0.0021772509312810245 - 6.994713684867517e-15im
#                        ⋮
#    0.00331804959311577 - 6.898951475196974e-15im
#  0.0032412880516003244 - 6.863985359183573e-15im
#  0.0031663023307306397 - 6.909394514822442e-15im
#  0.0030930513530286682 - 6.908135725903366e-15im
#   0.003021494990938943 - 6.927514492899693e-15im
# ...

# %%
imprint_vel_set_bar!(g1; vv=7.0, bb=1.)
show_psi_0(g1)
single_shot_dynamics(g1)
# Out:
# ┌ Info: (200,)
# └ @ Main /home/lorenzi/.julia/dev/CondensateDynamics/research/visual_utils.jl:5
# ...
